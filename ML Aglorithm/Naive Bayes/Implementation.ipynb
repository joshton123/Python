# %% [markdown]
# # Naives Bayes
# Naive Bayes classifiers are a collection of classification algorithms based on Bayes’ Theorem. It is not a single algorithm but a family of algorithms where all of them share a common principle, i.e. every pair of features being classified is independent of each other
#
# **variants of naive Bayes**
# 1. Bernoulli Naive Bayes
# 2. Multinomial Naive Bayes
# 3. Guassian Naive Bayes
#
# ### 1. Bernoulli Naive Bayes
#  * Whenever featire os following bernoulli disribution then use this
#  * bernouli (0,1)
#
# ### 2. Multinomial Naive Bayes
#   * If the input is text
#   * For egs Dataset is sentiment analysis
#
# ### 3. Guassian Naive Bayes
#   * if the features are following guassian distribution then we use his

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.model_selection import train_test_split

# %%
X,y = load_iris(return_X_y= True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1, 1, 1, 2, 0, 2, 0,
#        0])

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
# [[16  0  0]
#  [ 0 18  0]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# 1.0

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
X = df.drop('time', axis=1)
y = df.loc[:,'time']

# %%
from sklearn.preprocessing import OneHotEncoder
lab = OneHotEncoder()

# %%
lab.fit_transform(X,y)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1464 stored elements and shape (244, 366)>
